# %%
import numpy as np 
import pandas as pd 
import os

import matplotlib.pyplot as plt
import csv
import itertools
import collections

import pywt
from scipy import stats
from sklearn.metrics import classification_report
from sklearn.utils import resample
from sklearn.model_selection import train_test_split

import tensorflow as tf    # extra added line
import keras
from keras.models import Sequential
from keras.layers import Conv1D, AvgPool1D, Flatten, Dense, Dropout, Softmax, MaxPool1D
from keras.layers import GlobalAveragePooling1D     # extra added line
from tensorflow.keras.layers import GlobalAveragePooling1D, GlobalMaxPooling1D    # extra added line 
# from keras.optimizers import Adam 
from keras.utils.np_utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras import regularizers
#imports to apply k-fold validation
from sklearn.model_selection import KFold, cross_val_score

import seaborn as sns
from typing import Tuple
import copy as cp
from sklearn.metrics import confusion_matrix

# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = (30,6)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.color'] = 'b'
plt.rcParams['axes.grid'] = True

# %%
def denoise(data): 
    w = pywt.Wavelet('sym4')
    maxlev = pywt.dwt_max_level(len(data), w.dec_len)
    threshold = 0.04 # Threshold for filtering

    coeffs = pywt.wavedec(data, 'sym4', level=maxlev)
    for i in range(1, len(coeffs)):
        coeffs[i] = pywt.threshold(coeffs[i], threshold*max(coeffs[i]))
        
    datarec = pywt.waverec(coeffs, 'sym4')
    
    return datarec

# %%
path = 'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/'
window_size = 180
maximum_counting = 10000

classes = ['N', 'L', 'R', 'A', 'V']
n_classes = len(classes)
count_classes = [0]*n_classes

X = list()
y = list()

# %%
# Read files
filenames = next(os.walk(path))[2]

# Split and save .csv , .txt 
records = list()
annotations = list()
filenames.sort()

# %%
print((filenames))
records_list_16 = ['100', '106', '107', '109', '111', '118', '124', '200', '201', '207', '208', '209', '212', '214', '231', '233']
annotations_list_16 = ['100', '106', '107', '109', '111', '118', '124', '200', '201', '207', '208', '209', '212', '214', '231', '233']
# Out:
# ['100.csv', '100annotations.txt', '101.csv', '101annotations.txt', '102.csv', '102annotations.txt', '103.csv', '103annotations.txt', '104.csv', '104annotations.txt', '105.csv', '105annotations.txt', '106.csv', '106annotations.txt', '107.csv', '107annotations.txt', '108.csv', '108annotations.txt', '109.csv', '109annotations.txt', '111.csv', '111annotations.txt', '112.csv', '112annotations.txt', '113.csv', '113annotations.txt', '114.csv', '114annotations.txt', '115.csv', '115annotations.txt', '116.csv', '116annotations.txt', '117.csv', '117annotations.txt', '118.csv', '118annotations.txt', '119.csv', '119annotations.txt', '121.csv', '121annotations.txt', '122.csv', '122annotations.txt', '123.csv', '123annotations.txt', '124.csv', '124annotations.txt', '200.csv', '200annotations.txt', '201.csv', '201annotations.txt', '202.csv', '202annotations.txt', '203.csv', '203annotations.txt', '205.csv', '205annotations.txt', '207.csv', '207annotations.txt', '208.csv', '208annotations.txt', '209.csv', '209annotations.txt', '210.csv', '210annotations.txt', '212.csv', '212annotations.txt', '213.csv', '213annotations.txt', '214.csv', '214annotations.txt', '215.csv', '215annotations.txt', '217.csv', '217annotations.txt', '219.csv', '219annotations.txt', '220.csv', '220annotations.txt', '221.csv', '221annotations.txt', '222.csv', '222annotations.txt', '223.csv', '223annotations.txt', '228.csv', '228annotations.txt', '230.csv', '230annotations.txt', '231.csv', '231annotations.txt', '232.csv', '232annotations.txt', '233.csv', '233annotations.txt', '234.csv', '234annotations.txt']

# %%
# segrefating filenames and annotations
for f in filenames:
    filename, file_extension = os.path.splitext(f)
    
    # *.csv
    if(file_extension == '.csv'):
        records.append(path + filename + file_extension)

    # *.txt
    else:
        annotations.append(path + filename + file_extension)

# %%
print(len(records))
print(len(annotations))
records
# Out:
# 48
# 48
# ['E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/100.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/101.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/102.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/103.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/104.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/105.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/106.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/107.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/108.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/109.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/111.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/112.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/113.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/114.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/115.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/116.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/117.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/118.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/119.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/121.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/122.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/123.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/124.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/200.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/201.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/202.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/203.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/205.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/207.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/208.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/209.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/210.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/212.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/213.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/214.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/215.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/217.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/219.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/220.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/221.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/222.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/223.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/228.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/230.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/231.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/232.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/233.csv',
#  'E:/OldDrive/Yasin/Fall2021/Neural_Network/Kimia/P3/mitbih_database/mitbih_database/234.csv']

# %%
# Records
for r in range(0,len(records)):
    signals = []

    with open(records[r], 'rt') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|') # read CSV file\
        row_index = -1
        for row in spamreader:
            if(row_index >= 0):
                signals.insert(row_index, int(row[1]))
            row_index += 1
            
    # Plot an example to the signals
    if r is 6:
        # Plot each patient's signal
        plt.title(records[6] + " Wave")
        plt.plot(signals[0:700])
        plt.show()
        
    signals = denoise(signals)
    # Plot an example to the signals
    if r is 6:
        # Plot each patient's signal
        plt.title(records[6] + " wave after denoised")
        plt.plot(signals[0:700])
        plt.show()
        
    signals = stats.zscore(signals)
    # Plot an example to the signals
    if r is 6:
        # Plot each patient's signal
        plt.title(records[6] + " wave after z-score normalization ")
        plt.plot(signals[0:700])
        plt.show()
    
    # Read anotations: R position and Arrhythmia class
    example_beat_printed = False
    with open(annotations[r], 'r') as fileID:
        data = fileID.readlines() 
        beat = list()

        for d in range(1, len(data)): # 0 index is Chart Head
            splitted = data[d].split(' ') #The split() method splits a string into a list.
            splitted = filter(None, splitted)
            next(splitted) # Time... Clipping
            pos = int(next(splitted)) # Sample ID
            arrhythmia_type = next(splitted) # Type
            if(arrhythmia_type in classes):
                arrhythmia_index = classes.index(arrhythmia_type)
           # if count_classes[arrhythmia_index] > maximum_counting: # avoid overfitting
                #    pass
            #else:
                count_classes[arrhythmia_index] += 1
                if(window_size <= pos and pos < (len(signals) - window_size)):
                    beat = signals[pos-window_size:pos+window_size]     ## REPLACE WITH R-PEAK DETECTION
                    # Plot an example to a beat    
                    if r is 6 and not example_beat_printed: 
                        plt.title("A Beat from " + records[6] + " Wave")
                        plt.plot(beat)
                        plt.show()
                        example_beat_printed = True

                    X.append(beat)
                    y.append(arrhythmia_index)

# data shape
print(np.shape(X), np.shape(y))
# Out:
# (100012, 360) (100012,)

# %%
for i in range(0,len(X)):
        X[i] = np.append(X[i], y[i])
#         X[i].append(y[i])

print(np.shape(X))
# Out:
# (100012, 361)

# %% [markdown]
# # Classes Distribution¶

# %%
X_train_df = pd.DataFrame(X)
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(30,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 0.0    75011
# 1.0     8071
# 2.0     7255
# 4.0     7129
# 3.0     2546
# Name: 360, dtype: int64

# %%
df_1=X_train_df[X_train_df[X_train_df.shape[1]-1]==1]
df_2=X_train_df[X_train_df[X_train_df.shape[1]-1]==2]
df_3=X_train_df[X_train_df[X_train_df.shape[1]-1]==3]
df_4=X_train_df[X_train_df[X_train_df.shape[1]-1]==4]
# df_5=X_train_df[X_train_df[X_train_df.shape[1]-1]==5]
df_0=(X_train_df[X_train_df[X_train_df.shape[1]-1]==0]).sample(n=6000,random_state=42)

df_1_upsample=resample(df_1,replace=True,n_samples=6000,random_state=122)
df_2_upsample=resample(df_2,replace=True,n_samples=6000,random_state=123)
df_3_upsample=resample(df_3,replace=True,n_samples=6000,random_state=124)
df_4_upsample=resample(df_4,replace=True,n_samples=6000,random_state=125)
# df_5_upsample=resample(df_5,replace=True,n_samples=5000,random_state=126)

# X_train_df=pd.concat([df_0,df_1_upsample,df_2_upsample,df_3_upsample,df_4_upsample,df_5_upsample])
X_train_df=pd.concat([df_0,df_1_upsample,df_2_upsample,df_3_upsample,df_4_upsample])

# %%
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 4.0    6000
# 3.0    6000
# 2.0    6000
# 1.0    6000
# 0.0    6000
# Name: 360, dtype: int64

# %%
train, test = train_test_split(X_train_df, test_size=0.20,random_state = 42)

print("X_train : ", np.shape(train))
print("X_test  : ", np.shape(test))
# Out:
# X_train :  (24000, 361)
# X_test  :  (6000, 361)

# %%
target_train=train[train.shape[1]-1]
target_test=test[test.shape[1]-1]
train_y=to_categorical(target_train)
test_y=to_categorical(target_test)
print(np.shape(train_y), np.shape(test_y))
# Out:
# (24000, 5) (6000, 5)

# %%
train_x = train.iloc[:,:train.shape[1]-1].values
test_x = test.iloc[:,:test.shape[1]-1].values
train_x = train_x.reshape(len(train_x), train_x.shape[1],1)
test_x = test_x.reshape(len(test_x), test_x.shape[1],1)
print(np.shape(train_x), np.shape(test_x))
# Out:
# (24000, 360, 1) (6000, 360, 1)

# %%
train_y[0]
# Out:
# array([0., 0., 0., 1., 0.], dtype=float32)

# %% [markdown]
# # Building the RNN Architecture¶

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Bidirectional, GlobalMaxPool1D,Conv1D, MaxPooling1D, SimpleRNN, GRU
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation

# %%
model = keras.Sequential()
# Add an Embedding layer expecting input vocab of size 1000, and
# output embedding dimension of size 64.
# model.add(layers.Embedding(input_dim=360, output_dim=360))
model.add(Bidirectional(LSTM(10, return_sequences=True),input_shape=(360, 1)))
# add a fully-connected recurrent layer
# model.add(SimpleRNN(64))
# # # Add a LSTM layer with 128 internal units.
model.add(layers.LSTM(128))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(6, activation='relu'))
# Add a Dense layer with 10 units.
model.add(layers.Dense(5, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_4 (Bidirection (None, 360, 20)           960
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 128)               76288
# _________________________________________________________________
# dense_44 (Dense)             (None, 100)               12900
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_46 (Dense)             (None, 6)                 306
# _________________________________________________________________
# dense_47 (Dense)             (None, 5)                 35
# =================================================================
# Total params: 95,539
# Trainable params: 95,539
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy'])

history = model.fit(
    train_x, train_y, validation_data=(test_x, test_y), batch_size=128, epochs=100
)
# Out:
# Epoch 1/100
# 188/188 [==============================] - 12s 51ms/step - loss: 1.2647 - accuracy: 0.4832 - val_loss: 1.0310 - val_accuracy: 0.6115
# Epoch 2/100
# 188/188 [==============================] - 9s 47ms/step - loss: 1.0071 - accuracy: 0.6230 - val_loss: 1.0234 - val_accuracy: 0.5978
# Epoch 3/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.8861 - accuracy: 0.6822 - val_loss: 0.7343 - val_accuracy: 0.7437
# Epoch 4/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.7797 - accuracy: 0.7202 - val_loss: 0.7522 - val_accuracy: 0.7292
# Epoch 5/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.7224 - accuracy: 0.7467 - val_loss: 0.6814 - val_accuracy: 0.7602
# Epoch 6/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.6249 - accuracy: 0.7845 - val_loss: 0.5801 - val_accuracy: 0.8028
# Epoch 7/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.5804 - accuracy: 0.8025 - val_loss: 0.5227 - val_accuracy: 0.8217
# Epoch 8/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.5310 - accuracy: 0.8221 - val_loss: 0.5254 - val_accuracy: 0.8245
# Epoch 9/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.4878 - accuracy: 0.8385 - val_loss: 0.4364 - val_accuracy: 0.8623
# Epoch 10/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.4535 - accuracy: 0.8510 - val_loss: 0.4060 - val_accuracy: 0.8687
# Epoch 11/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.4860 - accuracy: 0.8430 - val_loss: 0.4874 - val_accuracy: 0.8517
# Epoch 12/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.4372 - accuracy: 0.8605 - val_loss: 0.4212 - val_accuracy: 0.8672
# Epoch 13/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.4608 - accuracy: 0.8532 - val_loss: 0.4151 - val_accuracy: 0.8693
# Epoch 14/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.4340 - accuracy: 0.8621 - val_loss: 0.4243 - val_accuracy: 0.8627
# Epoch 15/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.3554 - accuracy: 0.8893 - val_loss: 0.3205 - val_accuracy: 0.8987
# Epoch 16/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.3442 - accuracy: 0.8930 - val_loss: 0.3646 - val_accuracy: 0.8927
# Epoch 17/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.3234 - accuracy: 0.8993 - val_loss: 0.3176 - val_accuracy: 0.8962
# Epoch 18/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.3352 - accuracy: 0.8963 - val_loss: 0.3086 - val_accuracy: 0.9000
# Epoch 19/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.3405 - accuracy: 0.8929 - val_loss: 0.2745 - val_accuracy: 0.9157
# Epoch 20/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.4065 - accuracy: 0.8735 - val_loss: 0.5067 - val_accuracy: 0.8453
# Epoch 21/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.3882 - accuracy: 0.8785 - val_loss: 0.3396 - val_accuracy: 0.8920
# Epoch 22/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.3139 - accuracy: 0.9032 - val_loss: 0.3393 - val_accuracy: 0.8962
# Epoch 23/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.3266 - accuracy: 0.8952 - val_loss: 0.3904 - val_accuracy: 0.8822
# Epoch 24/100
# 188/188 [==============================] - 9s 47ms/step - loss: 1.3624 - accuracy: 0.4116 - val_loss: 1.3533 - val_accuracy: 0.4208
# Epoch 25/100
# 188/188 [==============================] - 9s 48ms/step - loss: 1.2952 - accuracy: 0.4597 - val_loss: 1.5081 - val_accuracy: 0.3080
# Epoch 26/100
# 188/188 [==============================] - 9s 47ms/step - loss: 1.3556 - accuracy: 0.4390 - val_loss: 1.4576 - val_accuracy: 0.3390
# Epoch 27/100
# 188/188 [==============================] - 9s 47ms/step - loss: 1.1761 - accuracy: 0.5280 - val_loss: 1.1059 - val_accuracy: 0.5633
# Epoch 28/100
# 188/188 [==============================] - 9s 48ms/step - loss: 1.3725 - accuracy: 0.4137 - val_loss: 1.2933 - val_accuracy: 0.4765
# Epoch 29/100
# 188/188 [==============================] - 9s 47ms/step - loss: 1.2595 - accuracy: 0.4801 - val_loss: 1.1240 - val_accuracy: 0.5660
# Epoch 30/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.9687 - accuracy: 0.6382 - val_loss: 0.8010 - val_accuracy: 0.7195
# Epoch 31/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.8485 - accuracy: 0.6956 - val_loss: 0.7687 - val_accuracy: 0.7373
# Epoch 32/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.7095 - accuracy: 0.7629 - val_loss: 0.6612 - val_accuracy: 0.7732
# Epoch 33/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.6323 - accuracy: 0.7947 - val_loss: 0.5546 - val_accuracy: 0.8180
# Epoch 34/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.5421 - accuracy: 0.8242 - val_loss: 0.4897 - val_accuracy: 0.8382
# Epoch 35/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.5035 - accuracy: 0.8372 - val_loss: 0.5709 - val_accuracy: 0.8117
# Epoch 36/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.4516 - accuracy: 0.8508 - val_loss: 0.4462 - val_accuracy: 0.8515
# Epoch 37/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.4428 - accuracy: 0.8534 - val_loss: 0.4557 - val_accuracy: 0.8477
# Epoch 38/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.4106 - accuracy: 0.8619 - val_loss: 0.4046 - val_accuracy: 0.8642
# Epoch 39/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.3629 - accuracy: 0.8795 - val_loss: 0.3582 - val_accuracy: 0.8823
# Epoch 40/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.3228 - accuracy: 0.8910 - val_loss: 0.3080 - val_accuracy: 0.8932
# Epoch 41/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.3090 - accuracy: 0.8965 - val_loss: 0.3622 - val_accuracy: 0.8805
# Epoch 42/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.3827 - accuracy: 0.8748 - val_loss: 0.3537 - val_accuracy: 0.8828
# Epoch 43/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.2924 - accuracy: 0.9022 - val_loss: 0.2912 - val_accuracy: 0.9032
# Epoch 44/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.2917 - accuracy: 0.9023 - val_loss: 0.2982 - val_accuracy: 0.9018
# Epoch 45/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.2513 - accuracy: 0.9154 - val_loss: 0.2314 - val_accuracy: 0.9190
# Epoch 46/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.2170 - accuracy: 0.9268 - val_loss: 0.1978 - val_accuracy: 0.9330
# Epoch 47/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.2082 - accuracy: 0.9277 - val_loss: 0.2346 - val_accuracy: 0.9225
# Epoch 48/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1908 - accuracy: 0.9332 - val_loss: 0.2002 - val_accuracy: 0.9268
# Epoch 49/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1828 - accuracy: 0.9388 - val_loss: 0.1807 - val_accuracy: 0.9382
# Epoch 50/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1626 - accuracy: 0.9437 - val_loss: 0.1760 - val_accuracy: 0.9393
# Epoch 51/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1631 - accuracy: 0.9435 - val_loss: 0.1975 - val_accuracy: 0.9323
# Epoch 52/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1603 - accuracy: 0.9465 - val_loss: 0.1749 - val_accuracy: 0.9418
# Epoch 53/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.2009 - accuracy: 0.9337 - val_loss: 0.1768 - val_accuracy: 0.9340
# Epoch 54/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1563 - accuracy: 0.9456 - val_loss: 0.1443 - val_accuracy: 0.9453
# Epoch 55/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1396 - accuracy: 0.9534 - val_loss: 0.1301 - val_accuracy: 0.9582
# Epoch 56/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1307 - accuracy: 0.9552 - val_loss: 0.1259 - val_accuracy: 0.9555
# Epoch 57/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1237 - accuracy: 0.9575 - val_loss: 0.1505 - val_accuracy: 0.9538
# Epoch 58/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1170 - accuracy: 0.9603 - val_loss: 0.1381 - val_accuracy: 0.9545
# Epoch 59/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1120 - accuracy: 0.9632 - val_loss: 0.1306 - val_accuracy: 0.9558
# Epoch 60/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1219 - accuracy: 0.9585 - val_loss: 0.1192 - val_accuracy: 0.9610
# Epoch 61/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1129 - accuracy: 0.9610 - val_loss: 0.1378 - val_accuracy: 0.9495
# Epoch 62/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1082 - accuracy: 0.9637 - val_loss: 0.1205 - val_accuracy: 0.9603
# Epoch 63/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1049 - accuracy: 0.9640 - val_loss: 0.1235 - val_accuracy: 0.9562
# Epoch 64/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0997 - accuracy: 0.9667 - val_loss: 0.1266 - val_accuracy: 0.9620
# Epoch 65/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.0978 - accuracy: 0.9668 - val_loss: 0.1210 - val_accuracy: 0.9565
# Epoch 66/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.1006 - accuracy: 0.9653 - val_loss: 0.1211 - val_accuracy: 0.9620
# Epoch 67/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0894 - accuracy: 0.9680 - val_loss: 0.1212 - val_accuracy: 0.9597
# Epoch 68/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0783 - accuracy: 0.9728 - val_loss: 0.0915 - val_accuracy: 0.9688
# Epoch 69/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.0856 - accuracy: 0.9695 - val_loss: 0.0925 - val_accuracy: 0.9680
# Epoch 70/100
# 188/188 [==============================] - 9s 49ms/step - loss: 0.0936 - accuracy: 0.9672 - val_loss: 0.1005 - val_accuracy: 0.9670
# Epoch 71/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0829 - accuracy: 0.9721 - val_loss: 0.0913 - val_accuracy: 0.9697
# Epoch 72/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0769 - accuracy: 0.9738 - val_loss: 0.1009 - val_accuracy: 0.9673
# Epoch 73/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0769 - accuracy: 0.9731 - val_loss: 0.0904 - val_accuracy: 0.9698
# Epoch 74/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0671 - accuracy: 0.9761 - val_loss: 0.0920 - val_accuracy: 0.9705
# Epoch 75/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.0714 - accuracy: 0.9744 - val_loss: 0.0926 - val_accuracy: 0.9683
# Epoch 76/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.0677 - accuracy: 0.9773 - val_loss: 0.0992 - val_accuracy: 0.9672
# Epoch 77/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.0705 - accuracy: 0.9750 - val_loss: 0.0900 - val_accuracy: 0.9697
# Epoch 78/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0706 - accuracy: 0.9757 - val_loss: 0.0908 - val_accuracy: 0.9713
# Epoch 79/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0686 - accuracy: 0.9760 - val_loss: 0.0963 - val_accuracy: 0.9673
# Epoch 80/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.0800 - val_accuracy: 0.9743
# Epoch 81/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0653 - accuracy: 0.9785 - val_loss: 0.1131 - val_accuracy: 0.9625
# Epoch 82/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.0607 - accuracy: 0.9796 - val_loss: 0.0899 - val_accuracy: 0.9687
# Epoch 83/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0725 - accuracy: 0.9757 - val_loss: 0.0912 - val_accuracy: 0.9682
# Epoch 84/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0614 - accuracy: 0.9799 - val_loss: 0.1015 - val_accuracy: 0.9637
# Epoch 85/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.0555 - accuracy: 0.9815 - val_loss: 0.0770 - val_accuracy: 0.9733
# Epoch 86/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.0525 - accuracy: 0.9820 - val_loss: 0.0863 - val_accuracy: 0.9727
# Epoch 87/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.0449 - accuracy: 0.9847 - val_loss: 0.0610 - val_accuracy: 0.9785
# Epoch 88/100
# 188/188 [==============================] - 9s 49ms/step - loss: 0.0431 - accuracy: 0.9850 - val_loss: 0.0744 - val_accuracy: 0.9763
# Epoch 89/100
# 188/188 [==============================] - 9s 47ms/step - loss: 0.0499 - accuracy: 0.9838 - val_loss: 0.0913 - val_accuracy: 0.9733
# Epoch 90/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.0532 - accuracy: 0.9824 - val_loss: 0.0809 - val_accuracy: 0.9760
# Epoch 91/100
# 188/188 [==============================] - 10s 51ms/step - loss: 0.0528 - accuracy: 0.9820 - val_loss: 0.0796 - val_accuracy: 0.9770
# Epoch 92/100
# 188/188 [==============================] - 11s 56ms/step - loss: 0.0486 - accuracy: 0.9839 - val_loss: 0.0799 - val_accuracy: 0.9752
# Epoch 93/100
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0578 - accuracy: 0.9805 - val_loss: 0.0794 - val_accuracy: 0.9752
# Epoch 94/100
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0535 - accuracy: 0.9833 - val_loss: 0.0749 - val_accuracy: 0.9778
# Epoch 95/100
# 188/188 [==============================] - 9s 49ms/step - loss: 0.0386 - accuracy: 0.9882 - val_loss: 0.0731 - val_accuracy: 0.9772
# Epoch 96/100
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0341 - accuracy: 0.9887 - val_loss: 0.0724 - val_accuracy: 0.9802
# Epoch 97/100
# 188/188 [==============================] - 9s 49ms/step - loss: 0.0468 - accuracy: 0.9851 - val_loss: 0.0842 - val_accuracy: 0.9728
# Epoch 98/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.0381 - accuracy: 0.9882 - val_loss: 0.0813 - val_accuracy: 0.9758
# Epoch 99/100
# 188/188 [==============================] - 9s 48ms/step - loss: 0.0451 - accuracy: 0.9863 - val_loss: 0.0863 - val_accuracy: 0.9702
# Epoch 100/100
# 188/188 [==============================] - 9s 49ms/step - loss: 0.0391 - accuracy: 0.9867 - val_loss: 0.0795 - val_accuracy: 0.9772

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
score = model.evaluate(test_x, test_y)

print('Test Loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 188/188 [==============================] - 4s 22ms/step - loss: 0.0794 - accuracy: 0.9772
# Test Loss: 0.07943896949291229
# Test accuracy: 0.9771666526794434

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score

import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
y_true=[]
for element in test_y:
    y_true.append(np.argmax(element))
prediction_proba=model.predict(test_x)
prediction=np.argmax(prediction_proba,axis=1)
print(classification_report(y_true, prediction, target_names=classes))
custCnnConfMat = confusion_matrix(y_true, prediction)
sns.heatmap(custCnnConfMat/np.sum(custCnnConfMat), annot=True,fmt='.3%', cmap='Blues')
plt.savefig('custCnnconfMat.png')
# Out:
#               precision    recall  f1-score   support
#
#            N       0.96      0.96      0.96      1179
#            L       0.99      0.98      0.99      1244
#            R       0.99      0.99      0.99      1216
#            A       0.97      0.97      0.97      1171
#            V       0.98      0.99      0.98      1190
#
#     accuracy                           0.98      6000
#    macro avg       0.98      0.98      0.98      6000
# weighted avg       0.98      0.98      0.98      6000

# %%
print('Precision: %.3f' % precision_score(y_true, prediction, average='micro'))
print('F1 Score: %.3f' % f1_score(y_true, prediction, average='micro'))
print('Recall: %.3f' % recall_score(y_true, prediction, average='micro'))
print('Accuracy: %.3f' % accuracy_score(y_true, prediction))
# Out:
# Precision: 0.977
# F1 Score: 0.977
# Recall: 0.977
# Accuracy: 0.977
